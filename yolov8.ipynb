# %%
# !nvidia-smi
# Out:
# Fri Mar 21 12:02:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NJhhzff4SUKAVfGkXgGK")
project = rf.workspace("tugas-paper").project("strawberry-ripe-cqzdq-njuhr")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Strawberry-Ripe-2 in yolov8:: 100%|██████████| 15904/15904 [00:02<00:00, 5378.90it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 278MB/s]
# New https://pypi.org/project/ultralytics/8.3.94 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %%
# !zip -r my_project.zip /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Strawberry-Ripe-2/train/labels/212_png.rf.ed7af8e572c83de5c117ef9d851e2f9f.txt (deflated 54%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG2-39-_jpg.rf.3b5c3b681c5353016bb36057ea533cd7.txt (deflated 29%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG4-139-_jpg.rf.72498d99e6ba19bb57c5f1bc055d9c89.txt (deflated 23%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG2-139-_jpg.rf.eb9e16b30e64cfc1a08e29936b5fac2f.txt (deflated 18%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG1-39-_jpg.rf.ae6d7c03a45c384e65b56ea04246d915.txt (deflated 22%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG1-30-_jpg.rf.70669bf5b7390af73fcb1614c2207c01.txt (deflated 16%)
#   adding: content/Strawberry-Ripe-2/train/labels/IMG3-199-_jpg.rf.2bd3e8faf90aaa7815f33005476e5b94.txt (deflated 18%)
# ...

# %%
from google.colab import files
files.download('/content/my_project.zip')
